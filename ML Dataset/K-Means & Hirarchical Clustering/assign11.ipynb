# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset={
    'Points':['P1','P2','P3','P4','P5','P6','P7','P8'],
    'x_coordinate':[0.1,0.15,0.08,0.16,0.2,0.25,0.24,0.3],
    'y_coordinate':[0.6,0.71,0.9,0.85,0.3,0.5,0.1,0.2]
}

# %%
df=pd.DataFrame(dataset,columns=['Points','x_coordinate','y_coordinate'])

# %%
df
# Out:
#   Points  x_coordinate  y_coordinate
# 0     P1          0.10          0.60
# 1     P2          0.15          0.71
# 2     P3          0.08          0.90
# 3     P4          0.16          0.85
# 4     P5          0.20          0.30
# 5     P6          0.25          0.50
# 6     P7          0.24          0.10
# 7     P8          0.30          0.20

# %%
X=df.iloc[:,[1,2]].values

# %%
from sklearn.cluster import KMeans
wcss=[]

for i in range(1,6):
    kmeans=KMeans(n_clusters=i,init="k-means++",max_iter=100,random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
# Out:
# c:\Users\sahil\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(range(1,6),wcss)

# %%
kmeans=KMeans(n_clusters=3,init="k-means++",random_state=34)
ypred=kmeans.fit_predict(X)

# %%
centroid_m1=list(X[0])
centroid_m2=list(X[4])
centroid_m3=list(X[7])
plt.scatter(centroid_m1[0],centroid_m1[1],marker='*',s=200,c='g')
plt.scatter(centroid_m2[0],centroid_m2[1],marker='*',s=200,c='g')
plt.scatter(centroid_m3[0],centroid_m3[1],marker='*',s=200,c='g')
plt.scatter(X[ypred==0,0],X[ypred==0,1],s=50,c='blue',label="c1")
plt.scatter(X[ypred==1,0],X[ypred==1,1],s=50,c='red',label="c2")
plt.scatter(X[ypred==2,0],X[ypred==2,1],s=50,c='green',label="c3")

# %%
plt.scatter(X[ypred==0,0],X[ypred==0,1],s=50,c='blue',label="c1")
plt.scatter(X[ypred==1,0],X[ypred==1,1],s=50,c='red',label="c2")
plt.scatter(X[ypred==2,0],X[ypred==2,1],s=50,c='green',label="c3")
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='yellow',label='centroids')
plt.xlabel('points')
# Out:
# Text(0.5, 0, 'points')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pima-indians-diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Class
# 0                     0.627   50      1
# 1                     0.351   31      0
# 2                     0.672   32      1
# 3                     0.167   21      0
# 4                     2.288   33      1

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Class                       0
# dtype: int64

# %%
X = df.drop(['Class'],axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.25,random_state=123)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %%
clf = DecisionTreeClassifier()

# %%
clf = clf.fit(X_train, Y_train)

# %%
y_pred = clf.predict(X_test)

# %%
print("confusion matrix:\n")
print(metrics.confusion_matrix(Y_test, y_pred))
# Out:
# confusion matrix:
#
# [[85 34]
#  [20 53]]

# %%
import sklearn.tree
from sklearn.tree import DecisionTreeClassifier 
model=DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30))
tree.plot_tree(model, filled=True, fontsize=16)
# Out:
# [Text(0.5432972710253456, 0.96875, 'X[1] <= 144.5\ngini = 0.448\nsamples = 576\nvalue = [381, 195]'),
#  Text(0.2110185051843318, 0.90625, 'X[5] <= 26.9\ngini = 0.362\nsamples = 447\nvalue = [341, 106]'),
#  Text(0.059907834101382486, 0.84375, 'X[5] <= 26.35\ngini = 0.062\nsamples = 124\nvalue = [120, 4]'),
#  Text(0.03686635944700461, 0.78125, 'X[7] <= 59.0\ngini = 0.035\nsamples = 112\nvalue = [110, 2]'),
#  Text(0.018433179723502304, 0.71875, 'X[6] <= 0.675\ngini = 0.019\nsamples = 106\nvalue = [105, 1]'),
#  Text(0.009216589861751152, 0.65625, 'gini = 0.0\nsamples = 88\nvalue = [88, 0]'),
#  Text(0.027649769585253458, 0.65625, 'X[6] <= 0.688\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.018433179723502304, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03686635944700461, 0.59375, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.055299539170506916, 0.71875, 'X[6] <= 0.343\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.04608294930875576, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06451612903225806, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.08294930875576037, 0.78125, 'X[3] <= 22.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.07373271889400922, 0.71875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.09216589861751152, 0.71875, 'X[0] <= 2.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.08294930875576037, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10138248847926268, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3621291762672811, 0.84375, 'X[7] <= 30.5\ngini = 0.432\nsamples = 323\nvalue = [221, 102]'),
#  Text(0.18001152073732718, 0.78125, 'X[2] <= 37.0\ngini = 0.316\nsamples = 183\nvalue = [147, 36]'),
#  Text(0.12903225806451613, 0.71875, 'X[0] <= 7.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.11981566820276497, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.1382488479262673, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23099078341013826, 0.71875, 'X[1] <= 108.5\ngini = 0.289\nsamples = 177\nvalue = [146, 31]'),
#  Text(0.15668202764976957, 0.65625, 'X[6] <= 0.744\ngini = 0.145\nsamples = 89\nvalue = [82, 7]'),
#  Text(0.1336405529953917, 0.59375, 'X[5] <= 37.3\ngini = 0.093\nsamples = 82\nvalue = [78, 4]'),
#  Text(0.1152073732718894, 0.53125, 'X[2] <= 51.0\ngini = 0.032\nsamples = 62\nvalue = [61, 1]'),
#  Text(0.10599078341013825, 0.46875, 'X[3] <= 31.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.0967741935483871, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1152073732718894, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12442396313364056, 0.46875, 'gini = 0.0\nsamples = 57\nvalue = [57, 0]'),
#  Text(0.15207373271889402, 0.53125, 'X[4] <= 154.0\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.14285714285714285, 0.46875, 'X[5] <= 37.45\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.1336405529953917, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15207373271889402, 0.40625, 'X[3] <= 41.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.14285714285714285, 0.34375, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.16129032258064516, 0.34375, 'X[4] <= 24.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.15207373271889402, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17050691244239632, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.16129032258064516, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17972350230414746, 0.59375, 'X[4] <= 67.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.17050691244239632, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1889400921658986, 0.53125, 'X[5] <= 31.85\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.17972350230414746, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19815668202764977, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3052995391705069, 0.65625, 'X[0] <= 4.5\ngini = 0.397\nsamples = 88\nvalue = [64, 24]'),
#  Text(0.27419354838709675, 0.59375, 'X[6] <= 0.531\ngini = 0.356\nsamples = 82\nvalue = [63, 19]'),
#  Text(0.23963133640552994, 0.53125, 'X[1] <= 139.0\ngini = 0.204\nsamples = 52\nvalue = [46, 6]'),
#  Text(0.21658986175115208, 0.46875, 'X[4] <= 232.5\ngini = 0.15\nsamples = 49\nvalue = [45, 4]'),
#  Text(0.19815668202764977, 0.40625, 'X[0] <= 2.5\ngini = 0.12\nsamples = 47\nvalue = [44, 3]'),
#  Text(0.1889400921658986, 0.34375, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.2073732718894009, 0.34375, 'X[2] <= 55.0\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.19815668202764977, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21658986175115208, 0.28125, 'X[5] <= 31.75\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.2073732718894009, 0.21875, 'X[3] <= 6.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.19815668202764977, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.21658986175115208, 0.15625, 'X[4] <= 22.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.2073732718894009, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.22580645161290322, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22580645161290322, 0.21875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.2350230414746544, 0.40625, 'X[5] <= 38.7\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.22580645161290322, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24423963133640553, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2626728110599078, 0.46875, 'X[2] <= 74.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2534562211981567, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.271889400921659, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3087557603686636, 0.53125, 'X[1] <= 138.5\ngini = 0.491\nsamples = 30\nvalue = [17, 13]'),
#  Text(0.2995391705069124, 0.46875, 'X[6] <= 0.55\ngini = 0.499\nsamples = 25\nvalue = [12, 13]'),
#  Text(0.2903225806451613, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3087557603686636, 0.40625, 'X[5] <= 30.3\ngini = 0.49\nsamples = 21\nvalue = [12, 9]'),
#  Text(0.2995391705069124, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.31797235023041476, 0.34375, 'X[5] <= 33.9\ngini = 0.498\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.3087557603686636, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3271889400921659, 0.28125, 'X[3] <= 43.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.31797235023041476, 0.21875, 'X[7] <= 28.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.3087557603686636, 0.15625, 'X[7] <= 22.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.2995391705069124, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31797235023041476, 0.09375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.3271889400921659, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.33640552995391704, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.31797235023041476, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.33640552995391704, 0.59375, 'X[6] <= 0.39\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.3271889400921659, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3456221198156682, 0.53125, 'X[7] <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.33640552995391704, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3548387096774194, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.544246831797235, 0.78125, 'X[1] <= 94.5\ngini = 0.498\nsamples = 140\nvalue = [74, 66]'),
#  Text(0.45910138248847926, 0.71875, 'X[6] <= 1.16\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.4498847926267281, 0.65625, 'X[1] <= 28.5\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.440668202764977, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45910138248847926, 0.59375, 'X[0] <= 11.5\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(0.4498847926267281, 0.53125, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.4683179723502304, 0.53125, 'X[5] <= 31.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.45910138248847926, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47753456221198154, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4683179723502304, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6293922811059908, 0.71875, 'X[7] <= 56.5\ngini = 0.493\nsamples = 113\nvalue = [50, 63]'),
#  Text(0.5813652073732719, 0.65625, 'X[6] <= 0.528\ngini = 0.481\nsamples = 102\nvalue = [41, 61]'),
#  Text(0.5313940092165899, 0.59375, 'X[3] <= 37.5\ngini = 0.499\nsamples = 74\nvalue = [35, 39]'),
#  Text(0.505184331797235, 0.53125, 'X[3] <= 34.0\ngini = 0.487\nsamples = 62\nvalue = [26, 36]'),
#  Text(0.4959677419354839, 0.46875, 'X[4] <= 187.0\ngini = 0.495\nsamples = 58\nvalue = [26, 32]'),
#  Text(0.45276497695852536, 0.40625, 'X[2] <= 83.0\ngini = 0.482\nsamples = 52\nvalue = [21, 31]'),
#  Text(0.39400921658986177, 0.34375, 'X[6] <= 0.125\ngini = 0.411\nsamples = 38\nvalue = [11, 27]'),
#  Text(0.3640552995391705, 0.28125, 'X[7] <= 45.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3548387096774194, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.37327188940092165, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.423963133640553, 0.28125, 'X[1] <= 125.5\ngini = 0.36\nsamples = 34\nvalue = [8, 26]'),
#  Text(0.391705069124424, 0.21875, 'X[3] <= 26.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.3824884792626728, 0.15625, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.4009216589861751, 0.15625, 'X[1] <= 108.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.391705069124424, 0.09375, 'X[1] <= 98.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3824884792626728, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4009216589861751, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.41013824884792627, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.45622119815668205, 0.21875, 'X[1] <= 129.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.4377880184331797, 0.15625, 'X[7] <= 46.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.42857142857142855, 0.09375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4470046082949309, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47465437788018433, 0.15625, 'X[5] <= 28.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.46543778801843316, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4838709677419355, 0.09375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.511520737327189, 0.34375, 'X[2] <= 93.0\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.4930875576036866, 0.28125, 'X[4] <= 125.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.4838709677419355, 0.21875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5023041474654378, 0.21875, 'X[1] <= 125.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4930875576036866, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.511520737327189, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5299539170506913, 0.28125, 'X[6] <= 0.259\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5207373271889401, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5391705069124424, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5391705069124424, 0.40625, 'X[6] <= 0.192\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.5299539170506913, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5483870967741935, 0.34375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5144009216589862, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5576036866359447, 0.53125, 'X[4] <= 85.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.5483870967741935, 0.46875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5668202764976958, 0.46875, 'X[0] <= 8.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5576036866359447, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.576036866359447, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.631336405529954, 0.59375, 'X[0] <= 6.5\ngini = 0.337\nsamples = 28\nvalue = [6, 22]'),
#  Text(0.6221198156682027, 0.53125, 'X[1] <= 110.0\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.6036866359447005, 0.46875, 'X[5] <= 33.05\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.5944700460829493, 0.40625, 'X[3] <= 32.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5852534562211982, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6036866359447005, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6129032258064516, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6405529953917051, 0.46875, 'X[2] <= 25.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.631336405529954, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6497695852534562, 0.40625, 'X[4] <= 218.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.6405529953917051, 0.34375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.6589861751152074, 0.34375, 'X[0] <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6497695852534562, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6682027649769585, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6405529953917051, 0.53125, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6774193548387096, 0.65625, 'X[3] <= 40.0\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.6682027649769585, 0.59375, 'X[6] <= 0.714\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.6589861751152074, 0.53125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6774193548387096, 0.53125, 'X[6] <= 1.091\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6682027649769585, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6866359447004609, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6866359447004609, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8755760368663594, 0.90625, 'X[1] <= 166.5\ngini = 0.428\nsamples = 129\nvalue = [40, 89]'),
#  Text(0.7788018433179723, 0.84375, 'X[7] <= 24.5\ngini = 0.49\nsamples = 72\nvalue = [31, 41]'),
#  Text(0.7373271889400922, 0.78125, 'X[7] <= 21.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.728110599078341, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7465437788018433, 0.71875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8202764976958525, 0.78125, 'X[6] <= 0.343\ngini = 0.469\nsamples = 64\nvalue = [24, 40]'),
#  Text(0.7649769585253456, 0.71875, 'X[3] <= 28.0\ngini = 0.499\nsamples = 31\nvalue = [16, 15]'),
#  Text(0.7419354838709677, 0.65625, 'X[7] <= 53.5\ngini = 0.472\nsamples = 21\nvalue = [8, 13]'),
#  Text(0.7235023041474654, 0.59375, 'X[5] <= 29.2\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.7142857142857143, 0.53125, 'X[0] <= 8.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.7050691244239631, 0.46875, 'X[2] <= 32.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.695852534562212, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7142857142857143, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7235023041474654, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7327188940092166, 0.53125, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.7603686635944701, 0.59375, 'X[7] <= 68.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.7511520737327189, 0.53125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7695852534562212, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7880184331797235, 0.65625, 'X[5] <= 28.85\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.7788018433179723, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7972350230414746, 0.59375, 'X[3] <= 43.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.7880184331797235, 0.53125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.8064516129032258, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8755760368663594, 0.71875, 'X[0] <= 6.5\ngini = 0.367\nsamples = 33\nvalue = [8, 25]'),
#  Text(0.8525345622119815, 0.65625, 'X[0] <= 4.5\ngini = 0.465\nsamples = 19\nvalue = [7, 12]'),
#  Text(0.8341013824884793, 0.59375, 'X[1] <= 148.0\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.8248847926267281, 0.53125, 'X[5] <= 42.35\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.815668202764977, 0.46875, 'X[2] <= 87.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8064516129032258, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8248847926267281, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8341013824884793, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8433179723502304, 0.53125, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8709677419354839, 0.59375, 'X[7] <= 49.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.8617511520737328, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.880184331797235, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8986175115207373, 0.65625, 'X[0] <= 12.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.8894009216589862, 0.59375, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.9078341013824884, 0.59375, 'X[6] <= 0.995\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8986175115207373, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9170506912442397, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9723502304147466, 0.84375, 'X[5] <= 23.1\ngini = 0.266\nsamples = 57\nvalue = [9, 48]'),
#  Text(0.9631336405529954, 0.78125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9815668202764977, 0.78125, 'X[4] <= 661.5\ngini = 0.245\nsamples = 56\nvalue = [8, 48]'),
#  Text(0.9723502304147466, 0.71875, 'X[7] <= 66.5\ngini = 0.222\nsamples = 55\nvalue = [7, 48]'),
#  Text(0.9631336405529954, 0.65625, 'X[2] <= 93.0\ngini = 0.198\nsamples = 54\nvalue = [6, 48]'),
#  Text(0.9447004608294931, 0.59375, 'X[0] <= 3.5\ngini = 0.147\nsamples = 50\nvalue = [4, 46]'),
#  Text(0.9354838709677419, 0.53125, 'X[7] <= 55.5\ngini = 0.252\nsamples = 27\nvalue = [4, 23]'),
#  Text(0.9262672811059908, 0.46875, 'X[3] <= 16.5\ngini = 0.204\nsamples = 26\nvalue = [3, 23]'),
#  Text(0.9078341013824884, 0.40625, 'X[5] <= 31.45\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8986175115207373, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9170506912442397, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9447004608294931, 0.40625, 'X[2] <= 65.0\ngini = 0.087\nsamples = 22\nvalue = [1, 21]'),
#  Text(0.9354838709677419, 0.34375, 'X[4] <= 114.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9262672811059908, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9447004608294931, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9539170506912442, 0.34375, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.9447004608294931, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9539170506912442, 0.53125, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(0.9815668202764977, 0.59375, 'X[7] <= 44.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9723502304147466, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9907834101382489, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9815668202764977, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9907834101382489, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
print("1. Accuracy Score:", metrics.accuracy_score(Y_test, y_pred))
print("2. Precision Score:",metrics.precision_score(Y_test, y_pred))
print("3. Recall Score:", metrics.recall_score(Y_test, y_pred))
print("4. f1 Score:", metrics.f1_score(Y_test, y_pred))
# Out:
# 1. Accuracy Score: 0.71875
# 2. Precision Score: 0.6091954022988506
# 3. Recall Score: 0.726027397260274
# 4. f1 Score: 0.6625

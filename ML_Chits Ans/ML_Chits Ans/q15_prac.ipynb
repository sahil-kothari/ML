# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pip install apyori
# Out:
# ...
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for apyori, since package 'wheel' is not installed.
# ...
#   Running setup.py install for apyori: started
#   Running setup.py install for apyori: finished with status 'done'
# ...

# %%
from apyori import apriori

# %%
df=pd.read_csv(r'\Users\shekhar\Desktop\ML Dataset\Apriori\Order1.csv')

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
transactions = []
for i in range(0, 10):
    transactions.append([str(df.values[i,j]) for j in range(0,3)])

# %%
rule_list = apriori(transactions, min_support = 0.003, min_confidence = 0.3, min_lift = 3, min_length = 2)

# %%
results = list(rule_list)
for i in results:
    print('\n')
    print(i)
    print('**********')
# Out:
# RelationRecord(items=frozenset({'3037', '01-02-2015'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'01-02-2015'}), items_add=frozenset({'3037'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'3037'}), items_add=frozenset({'01-02-2015'}), confidence=1.0, lift=10.0)])
# **********
#
#
# RelationRecord(items=frozenset({'01-02-2015', 'whole milk'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'01-02-2015'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'whole milk'}), items_add=frozenset({'01-02-2015'}), confidence=0.33333333333333337, lift=3.3333333333333335)])
# **********
#
#
# ...
